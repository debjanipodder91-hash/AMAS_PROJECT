# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from scipy.stats import genextreme
from scipy.special import gamma as gamma_func
import scipy
import pandas as pd
import time


save_files=True

directory = "data"
directory_results=directory+"/Results"

filelist = [
    "gev-mu=70,alpha=10,gamma=-0.3,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=0,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=0.1,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=0.2,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=0.3,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=0.4,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=0.5,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=0.6,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=0.7,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=0.8,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=0.9,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=1,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=1.1,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=1.2,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=1.3,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=1.4,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=1.5,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=1.6,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=1.7,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=1.8,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=1.9,N=e6.csv",
    "gev-mu=70,alpha=10,gamma=2,N=e6.csv"
    ]

# %%
for filename in filelist:
    # Load Data
    filepath = directory+ "/" + filename
    print(f"{filename}")
    df = pd.read_csv(filepath, header=None)
# Out:
# gev-mu=70,alpha=10,gamma=-0.3,N=e6.csv
# gev-mu=70,alpha=10,gamma=0,N=e6.csv
# gev-mu=70,alpha=10,gamma=0.1,N=e6.csv
# gev-mu=70,alpha=10,gamma=0.2,N=e6.csv
# gev-mu=70,alpha=10,gamma=0.3,N=e6.csv
# gev-mu=70,alpha=10,gamma=0.4,N=e6.csv
# gev-mu=70,alpha=10,gamma=0.5,N=e6.csv
# gev-mu=70,alpha=10,gamma=0.6,N=e6.csv
# gev-mu=70,alpha=10,gamma=0.7,N=e6.csv
# gev-mu=70,alpha=10,gamma=0.8,N=e6.csv
# gev-mu=70,alpha=10,gamma=0.9,N=e6.csv
# gev-mu=70,alpha=10,gamma=1,N=e6.csv
# gev-mu=70,alpha=10,gamma=1.1,N=e6.csv
# gev-mu=70,alpha=10,gamma=1.2,N=e6.csv
# gev-mu=70,alpha=10,gamma=1.3,N=e6.csv
# gev-mu=70,alpha=10,gamma=1.4,N=e6.csv
# gev-mu=70,alpha=10,gamma=1.5,N=e6.csv
# gev-mu=70,alpha=10,gamma=1.6,N=e6.csv
# gev-mu=70,alpha=10,gamma=1.7,N=e6.csv
# gev-mu=70,alpha=10,gamma=1.8,N=e6.csv
# gev-mu=70,alpha=10,gamma=1.9,N=e6.csv
# gev-mu=70,alpha=10,gamma=2,N=e6.csv

# %%
# Helper Functions

def weibull_plotting_positions(n):
    ranks = np.arange(1, n + 1)
    P = ranks / (n + 1)
    return P


def gev_pdf(x, mu, alpha, gamma):

    if abs(gamma) < 1e-10:
        y = (x - mu) / alpha
        return (1.0 / alpha) * np.exp(-y) * np.exp(-np.exp(-y))

    inner = 1.0 + gamma * (x - mu) / alpha
    inner = np.maximum(inner, 1e-12)

    return (1.0 / alpha) * inner ** (-(1.0 / gamma + 1.0)) * np.exp(-inner ** (-1.0 / gamma))


def gev_cdf(x, mu, alpha, gamma):

    if abs(gamma) < 1e-10:
        y = (x - mu) / alpha
        return np.exp(-np.exp(-y))

    inner = 1.0 + gamma * (x - mu) / alpha
    inner = np.maximum(inner, 1e-12)

    return np.exp(-inner ** (-1.0 / gamma))



def order_statistic_variance(m, N, mu, alpha, gamma):

    x_min = genextreme.ppf(1e-6, -gamma, loc=mu, scale=alpha)
    x_max = genextreme.ppf(1 - 1e-6, -gamma, loc=mu, scale=alpha)

    x_grid = np.linspace(x_min, x_max, 800)

    #print("calc F and f...")
    F_vals = gev_cdf(x_grid, mu, alpha, gamma)
    f_vals = gev_pdf(x_grid, mu, alpha, gamma)

    coeff = scipy.special.comb(N=N, k=m, exact=True)*m

    #print("calc fm_vals...")
    fm_vals = coeff * (F_vals ** (m - 1)) * ((1 - F_vals) ** (N - m)) * f_vals

    #print("calc mean...")
    mean_m = np.trapzoid(x_grid * fm_vals, x_grid)                              #integrating not from -inf to inf?
    
    #print("calc variance...")
    var_m  = np.trapzoid((x_grid - mean_m) ** 2 * fm_vals, x_grid)

    return max(var_m, 1e-12)



# VWLS fit
def fit_vwls(data, max_iterations=20, beta=0.001):

    x = np.sort(data)
    N = len(x)
    P = weibull_plotting_positions(N)


    def objective_initial(params):
        mu, alpha, gamma = params
        if alpha <= 0:
            return 1e12
        xi = genextreme.ppf(P, -gamma, loc=mu, scale=alpha)                     #minus? gamma
        return np.sum((x - xi) ** 2)

    init = [np.median(x), np.std(x), 0.1]

    res = minimize(objective_initial, init, method="Nelder-Mead")
    params = res.x

    k = 0

    for iteration in range(max_iterations):
        print(f"Iteration {iteration+1}/{max_iterations}, params: mu={params[0]:.6f}, alpha={params[1]:.6f}, gamma={params[2]:.6f}")
        mu, alpha, gamma = params

        # theoretical 
        xi_vals = genextreme.ppf(P, -gamma, loc=mu, scale=alpha)

        #print(f"xi_vals len: {len(xi_vals)}")
        #print("rejecting points...")
        #raise NotImplementedError("Stopping here to check xi_vals and rejection logic. Something weird is going on here at the rejection step.")
        while k < N - 5:

            denom = xi_vals[-1] - xi_vals[k]

            if denom < 1e-12:
                k += 1
                continue

            ratio = (xi_vals[k+1] - xi_vals[k]) / denom

            if ratio < beta:
                k += 1
            else:
                break

        if k > 0:
            x_fit = x[k:]
            P_fit = P[k:]
        else:
            x_fit = x
            P_fit = P
        print(f"rejected {k} points, remaining {len(x_fit)} points")
        N_remaining=len(x_fit)


        #print("calculating weights...")
        variances = np.zeros(N_remaining, dtype=np.float64)

        for m in range(1, N_remaining + 1):
            try:
                variances[m-1] = order_statistic_variance(m, N_remaining, mu, alpha, gamma)
            except:
                variances[m-1] = 1.0

        w_fit = 1 / variances
        w_fit = w_fit / w_fit.sum()


        #print("optimizing parameters...")
        def objective(params_opt):

            mu_opt, alpha_opt, gamma_opt = params_opt

            if alpha_opt <= 0:
                return 1e12

            xi = genextreme.ppf(P_fit, -gamma_opt, loc=mu_opt, scale=alpha_opt)

            residuals = x_fit - xi

            return np.sum(w_fit * residuals**2)

        result = minimize(
            objective,
            params,
            method='Nelder-Mead',
            options={'xatol':1e-6,'fatol':1e-8,'maxiter':2000}
        )

        new_params = result.x

        if np.max(np.abs(new_params - params)) < 1e-5:
            params = new_params
            break

        params = new_params

    mu, alpha, gamma = params

    return mu, max(alpha,1e-6), gamma,len(x_fit)



# MLE
def fit_mle(data):

    x = np.sort(data)
    c, mu, alpha = genextreme.fit(x)
    gamma = -c
    return mu, alpha, gamma,len(x)



# PWM
def fit_pwm(data):

    x = np.sort(data)
    n = len(x)
    P = weibull_plotting_positions(n)

    b0 = np.mean(x)
    b1 = np.mean(x * P)
    b2 = np.mean(x * P**2)

    c = (2*b1 - b0)/(3*b2 - b0) - np.log(2)/np.log(3)

    k = 7.859*c + 2.9554*c**2
    gamma = -k

    if abs(gamma) < 1e-6:

        alpha = (b0 - 2*b1)/(-np.log(2))
        mu = b0 + alpha*0.5772

    else:

        g = gamma_func(1 + k)

        denom = g*(1 - 2**(-k))

        if abs(denom) < 1e-10:
            return np.mean(x), np.std(x), 0

        alpha = k*(2*b1 - b0)/denom
        mu = b0 - alpha*(1 - g)/k

    return mu, max(alpha,1e-6), gamma,len(x)


# L-moments
def fit_lmoments(data):

    x = np.sort(data)
    n = len(x)

    c = np.arange(n)

    b0 = np.mean(x)
    b1 = np.sum(c/(n-1)*x)/n
    b2 = np.sum(c*(c-1)/((n-1)*(n-2))*x)/n

    l1 = b0
    l2 = 2*b1 - b0
    l3 = 6*b2 - 6*b1 + b0

    if abs(l2) < 1e-10:
        return np.mean(x), np.std(x), 0

    t3 = l3/l2

    z = 2/(3+t3) - np.log(2)/np.log(3)

    k = 7.859*z + 2.9554*z**2
    gamma = -k

    if abs(gamma) < 1e-6:

        alpha = l2/np.log(2)
        mu = l1 - 0.5772*alpha

    else:

        g = gamma_func(1+k)

        alpha = k*l2/(g*(1-2**(-k)))
        mu = l1 - alpha*(1-g)/k

    return mu, max(alpha,1e-6), gamma,len(x)

# %%
bin_array=[10,15,20,30,50,100,150,200]

for filename in filelist:
    # Load Data

    start_time = time.time()
    filepath = directory+ "/" + filename
    print(f"Filepath: {filepath}")
    df = pd.read_csv(filepath, header=None)

    data = df.values[:,0]

    for z in bin_array:
        print(f"Fitting with {z} bins...")


        # Fit all methods
        fits = {}
        data_subset = data[0:z]
        b=0.001

        fits['VWLS'] = fit_vwls(data_subset,beta=b)
        print("VWLS fit completed.")

        fits['MLE']  = fit_mle(data_subset)
        #print("MLE fit completed.")

        fits['PWM']  = fit_pwm(data_subset)
        #print("PWM fit completed.")

        fits['L-moments'] = fit_lmoments(data_subset)
        #print("L-moments fit completed.")


        #save in file
        if save_files:
            with open(f"{directory_results}/calc_param_for_c.csv", "a") as f:
                f.write(f"\n{filename};rej_b={b};n={len(data_subset):.1e}\n")
                for method,(mu,alpha,shape,n) in fits.items():
                    f.write(f"{method},mu={mu:.8f},alpha={alpha:.8f},gamma={shape:.8f},n={n}\n")
            print(f"Parameters saved to {directory_results}/calc_param_for_c.csv")

            with open(f"{directory_results}/fitted_files.csv", "a") as f:
                f.write(f"{filename};rej_b={b};n={len(data_subset):.1e}\n")

            print(f"took time: {time.time() - start_time:.2f} seconds")
            print("--------------------------------------------------\n\n")
# Out:
# Filepath: data/gev-mu=70,alpha=10,gamma=-0.3,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=70.118699, alpha=12.437886, gamma=-0.388161
# rejected 0 points, remaining 10 points
# Iteration 2/20, params: mu=70.118730, alpha=12.437898, gamma=-0.388166
# rejected 0 points, remaining 10 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.65 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=68.673695, alpha=13.391698, gamma=-0.322482
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=68.673708, alpha=13.391730, gamma=-0.322485
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.97 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=67.766991, alpha=10.775913, gamma=-0.180113
# rejected 0 points, remaining 20 points
# Iteration 2/20, params: mu=67.766952, alpha=10.775897, gamma=-0.180109
# rejected 0 points, remaining 20 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.40 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=67.585587, alpha=9.521915, gamma=-0.181113
# rejected 0 points, remaining 30 points
# Iteration 2/20, params: mu=67.585598, alpha=9.521899, gamma=-0.181120
# rejected 0 points, remaining 30 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.81 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=67.869059, alpha=9.622481, gamma=-0.195827
# rejected 0 points, remaining 50 points
# Iteration 2/20, params: mu=67.869043, alpha=9.622511, gamma=-0.195829
# rejected 0 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.31 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=68.744076, alpha=10.315201, gamma=-0.280093
# rejected 0 points, remaining 100 points
# Iteration 2/20, params: mu=68.744108, alpha=10.315151, gamma=-0.280090
# rejected 0 points, remaining 100 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.07 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=68.927843, alpha=10.241024, gamma=-0.286418
# rejected 0 points, remaining 150 points
# Iteration 2/20, params: mu=68.927865, alpha=10.241064, gamma=-0.286423
# rejected 0 points, remaining 150 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 4.20 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=69.414382, alpha=10.124981, gamma=-0.298655
# rejected 0 points, remaining 200 points
# Iteration 2/20, params: mu=69.414388, alpha=10.124950, gamma=-0.298653
# rejected 0 points, remaining 200 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 5.21 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=0,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=70.117636, alpha=12.338717, gamma=0.000268
# rejected 0 points, remaining 10 points
# Iteration 2/20, params: mu=70.117606, alpha=12.338681, gamma=0.000274
# rejected 0 points, remaining 10 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.69 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=69.004056, alpha=13.578718, gamma=0.010072
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=69.004023, alpha=13.578729, gamma=0.010074
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.14 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=67.837929, alpha=10.405965, gamma=0.138564
# rejected 0 points, remaining 20 points
# Iteration 2/20, params: mu=67.837932, alpha=10.405902, gamma=0.138568
# rejected 0 points, remaining 20 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.59 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=67.541083, alpha=8.734142, gamma=0.138620
# rejected 0 points, remaining 30 points
# Iteration 2/20, params: mu=67.541100, alpha=8.734075, gamma=0.138627
# rejected 0 points, remaining 30 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.04 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=67.998621, alpha=9.434228, gamma=0.062964
# rejected 0 points, remaining 50 points
# Iteration 2/20, params: mu=67.998577, alpha=9.434227, gamma=0.062966
# rejected 0 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.51 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=68.888077, alpha=10.221827, gamma=-0.008820
# rejected 0 points, remaining 100 points
# Iteration 2/20, params: mu=68.888109, alpha=10.221791, gamma=-0.008821
# rejected 0 points, remaining 100 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.18 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=69.156758, alpha=10.348890, gamma=-0.037070
# rejected 0 points, remaining 150 points
# Iteration 2/20, params: mu=69.156766, alpha=10.348932, gamma=-0.037075
# rejected 0 points, remaining 150 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 4.19 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=69.643501, alpha=10.339834, gamma=-0.051252
# rejected 0 points, remaining 200 points
# Iteration 2/20, params: mu=69.643526, alpha=10.339826, gamma=-0.051257
# rejected 0 points, remaining 200 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 5.26 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=0.1,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=70.097190, alpha=12.212018, gamma=0.138185
# rejected 0 points, remaining 10 points
# Iteration 2/20, params: mu=70.097176, alpha=12.212005, gamma=0.138189
# rejected 0 points, remaining 10 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.85 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=69.101377, alpha=13.744783, gamma=0.122176
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=69.101379, alpha=13.744802, gamma=0.122176
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.24 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=67.854814, alpha=10.350771, gamma=0.243797
# rejected 0 points, remaining 20 points
# Iteration 2/20, params: mu=67.854818, alpha=10.350789, gamma=0.243794
# rejected 0 points, remaining 20 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.74 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=67.530323, alpha=8.468924, gamma=0.246137
# rejected 0 points, remaining 30 points
# Iteration 2/20, params: mu=67.530301, alpha=8.468920, gamma=0.246137
# rejected 0 points, remaining 30 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.16 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=68.041984, alpha=9.487225, gamma=0.144353
# rejected 0 points, remaining 50 points
# Iteration 2/20, params: mu=68.042005, alpha=9.487238, gamma=0.144350
# rejected 0 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.64 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=68.930895, alpha=10.251856, gamma=0.080571
# rejected 0 points, remaining 100 points
# Iteration 2/20, params: mu=68.930855, alpha=10.251873, gamma=0.080569
# rejected 0 points, remaining 100 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.38 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=69.237534, alpha=10.502176, gamma=0.041923
# rejected 0 points, remaining 150 points
# Iteration 2/20, params: mu=69.237492, alpha=10.502146, gamma=0.041926
# rejected 0 points, remaining 150 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 4.29 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=69.723757, alpha=10.514466, gamma=0.027953
# rejected 0 points, remaining 200 points
# Iteration 2/20, params: mu=69.723770, alpha=10.514491, gamma=0.027951
# rejected 0 points, remaining 200 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 5.19 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=0.2,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=70.076741, alpha=12.028284, gamma=0.279226
# rejected 0 points, remaining 10 points
# Iteration 2/20, params: mu=70.076758, alpha=12.028313, gamma=0.279222
# rejected 0 points, remaining 10 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.55 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=69.190952, alpha=13.980252, gamma=0.233742
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=69.190924, alpha=13.980224, gamma=0.233744
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.96 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=67.862814, alpha=10.342660, gamma=0.348069
# rejected 0 points, remaining 20 points
# Iteration 2/20, params: mu=67.862812, alpha=10.342610, gamma=0.348072
# rejected 0 points, remaining 20 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.33 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=67.521172, alpha=8.213818, gamma=0.353425
# rejected 0 points, remaining 30 points
# Iteration 2/20, params: mu=67.521174, alpha=8.213875, gamma=0.353421
# rejected 0 points, remaining 30 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.64 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=68.078002, alpha=9.628899, gamma=0.222319
# rejected 0 points, remaining 50 points
# Iteration 2/20, params: mu=68.077980, alpha=9.628911, gamma=0.222317
# rejected 0 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.98 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=68.967110, alpha=10.325618, gamma=0.168949
# rejected 0 points, remaining 100 points
# Iteration 2/20, params: mu=68.967080, alpha=10.325609, gamma=0.168951
# rejected 0 points, remaining 100 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.43 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=69.312401, alpha=10.733031, gamma=0.118920
# rejected 0 points, remaining 150 points
# Iteration 2/20, params: mu=69.312395, alpha=10.733055, gamma=0.118917
# rejected 0 points, remaining 150 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.11 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=69.799587, alpha=10.758889, gamma=0.105404
# rejected 0 points, remaining 200 points
# Iteration 2/20, params: mu=69.799548, alpha=10.758876, gamma=0.105407
# rejected 0 points, remaining 200 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.86 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=0.3,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=70.063305, alpha=11.788789, gamma=0.422671
# rejected 0 points, remaining 10 points
# Iteration 2/20, params: mu=70.063316, alpha=11.788805, gamma=0.422668
# rejected 0 points, remaining 10 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.53 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=69.269914, alpha=14.303255, gamma=0.343928
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=69.269898, alpha=14.303245, gamma=0.343928
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.97 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=67.856596, alpha=10.392607, gamma=0.450943
# rejected 0 points, remaining 20 points
# Iteration 2/20, params: mu=67.856659, alpha=10.392576, gamma=0.450943
# rejected 0 points, remaining 20 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.33 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=67.511105, alpha=7.979575, gamma=0.459893
# rejected 0 points, remaining 30 points
# Iteration 2/20, params: mu=67.511105, alpha=7.979591, gamma=0.459892
# rejected 0 points, remaining 30 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.66 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=68.097993, alpha=9.881658, gamma=0.296437
# rejected 0 points, remaining 50 points
# Iteration 2/20, params: mu=68.097974, alpha=9.881688, gamma=0.296436
# rejected 0 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.03 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=68.991799, alpha=10.452188, gamma=0.256131
# rejected 0 points, remaining 100 points
# Iteration 2/20, params: mu=68.991769, alpha=10.452207, gamma=0.256130
# rejected 0 points, remaining 100 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.57 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=69.374057, alpha=11.053784, gamma=0.194007
# rejected 0 points, remaining 150 points
# Iteration 2/20, params: mu=69.374080, alpha=11.053744, gamma=0.194008
# rejected 0 points, remaining 150 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.21 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=69.864440, alpha=11.087296, gamma=0.181009
# rejected 0 points, remaining 200 points
# Iteration 2/20, params: mu=69.864396, alpha=11.087302, gamma=0.181012
# rejected 0 points, remaining 200 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.98 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=0.4,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=70.063240, alpha=11.499616, gamma=0.567852
# rejected 0 points, remaining 10 points
# Iteration 2/20, params: mu=70.063246, alpha=11.499573, gamma=0.567855
# rejected 0 points, remaining 10 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.71 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=69.332830, alpha=14.737591, gamma=0.451889
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=69.332851, alpha=14.737586, gamma=0.451890
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.06 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=67.828851, alpha=10.514276, gamma=0.551901
# rejected 0 points, remaining 20 points
# Iteration 2/20, params: mu=67.828859, alpha=10.514296, gamma=0.551899
# rejected 0 points, remaining 20 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.48 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=67.494849, alpha=7.778423, gamma=0.564902
# rejected 0 points, remaining 30 points
# Iteration 2/20, params: mu=67.494871, alpha=7.778398, gamma=0.564903
# rejected 0 points, remaining 30 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.66 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=68.090345, alpha=10.270951, gamma=0.366414
# rejected 0 points, remaining 50 points
# Iteration 2/20, params: mu=68.090327, alpha=10.270997, gamma=0.366412
# rejected 0 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.57 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=68.997825, alpha=10.640294, gamma=0.342022
# rejected 0 points, remaining 100 points
# Iteration 2/20, params: mu=68.997798, alpha=10.640260, gamma=0.342024
# rejected 0 points, remaining 100 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 4.99 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=69.413258, alpha=11.476235, gamma=0.267359
# rejected 0 points, remaining 150 points
# Iteration 2/20, params: mu=69.413211, alpha=11.476226, gamma=0.267360
# rejected 0 points, remaining 150 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 5.65 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=69.909012, alpha=11.517310, gamma=0.254647
# rejected 0 points, remaining 200 points
# Iteration 2/20, params: mu=69.909013, alpha=11.517371, gamma=0.254645
# rejected 0 points, remaining 200 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 6.37 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=0.5,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=70.081623, alpha=11.170524, gamma=0.714170
# rejected 0 points, remaining 10 points
# Iteration 2/20, params: mu=70.081646, alpha=11.170544, gamma=0.714167
# rejected 0 points, remaining 10 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.55 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=69.370640, alpha=15.312144, gamma=0.556887
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=69.370633, alpha=15.312107, gamma=0.556888
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.86 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=67.768987, alpha=10.723543, gamma=0.650436
# rejected 0 points, remaining 20 points
# Iteration 2/20, params: mu=67.768962, alpha=10.723566, gamma=0.650435
# rejected 0 points, remaining 20 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.16 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=67.464101, alpha=7.623347, gamma=0.667794
# rejected 0 points, remaining 30 points
# Iteration 2/20, params: mu=67.464099, alpha=7.623286, gamma=0.667797
# rejected 0 points, remaining 30 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.57 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=68.039785, alpha=10.826146, gamma=0.432086
# rejected 0 points, remaining 50 points
# Iteration 2/20, params: mu=68.039749, alpha=10.826174, gamma=0.432085
# rejected 0 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.95 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=68.976181, alpha=10.896466, gamma=0.426675
# rejected 0 points, remaining 100 points
# Iteration 2/20, params: mu=68.976154, alpha=10.896469, gamma=0.426675
# rejected 0 points, remaining 100 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.44 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=69.418437, alpha=12.011951, gamma=0.339183
# rejected 0 points, remaining 150 points
# Iteration 2/20, params: mu=69.418455, alpha=12.011911, gamma=0.339185
# rejected 0 points, remaining 150 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.02 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=69.919957, alpha=12.070948, gamma=0.326178
# rejected 0 points, remaining 200 points
# Iteration 2/20, params: mu=69.920005, alpha=12.070938, gamma=0.326178
# rejected 0 points, remaining 200 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.63 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=0.6,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=70.121898, alpha=10.813938, gamma=0.861050
# rejected 0 points, remaining 10 points
# Iteration 2/20, params: mu=70.121860, alpha=10.813948, gamma=0.861050
# rejected 0 points, remaining 10 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.66 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=69.369444, alpha=16.060464, gamma=0.658335
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=69.369458, alpha=16.060493, gamma=0.658333
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.98 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=67.662882, alpha=11.038183, gamma=0.746107
# rejected 0 points, remaining 20 points
# Iteration 2/20, params: mu=67.662849, alpha=11.038167, gamma=0.746108
# rejected 0 points, remaining 20 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.34 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=67.406911, alpha=7.526924, gamma=0.767969
# rejected 0 points, remaining 30 points
# Iteration 2/20, params: mu=67.406919, alpha=7.526943, gamma=0.767967
# rejected 0 points, remaining 30 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.73 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=67.926498, alpha=11.581937, gamma=0.493425
# rejected 0 points, remaining 50 points
# Iteration 2/20, params: mu=67.926536, alpha=11.581926, gamma=0.493425
# rejected 0 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.06 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=68.916672, alpha=11.224357, gamma=0.510244
# rejected 0 points, remaining 100 points
# Iteration 2/20, params: mu=68.916597, alpha=11.224358, gamma=0.510245
# rejected 0 points, remaining 100 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.57 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=69.376664, alpha=12.670807, gamma=0.409740
# rejected 0 points, remaining 150 points
# Iteration 2/20, params: mu=69.376631, alpha=12.670793, gamma=0.409741
# rejected 0 points, remaining 150 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.16 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=69.878072, alpha=12.775333, gamma=0.395480
# rejected 0 points, remaining 200 points
# Iteration 2/20, params: mu=69.878083, alpha=12.775360, gamma=0.395479
# rejected 0 points, remaining 200 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.86 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=0.7,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=70.185361, alpha=10.442628, gamma=1.008019
# rejected 0 points, remaining 10 points
# Iteration 2/20, params: mu=70.185343, alpha=10.442620, gamma=1.008020
# rejected 0 points, remaining 10 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.61 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=69.309985, alpha=17.021279, gamma=0.755818
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=69.309953, alpha=17.021268, gamma=0.755818
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.91 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=67.491920, alpha=11.477826, gamma=0.838575
# rejected 0 points, remaining 20 points
# Iteration 2/20, params: mu=67.491930, alpha=11.477837, gamma=0.838575
# rejected 0 points, remaining 20 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.25 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=67.307697, alpha=7.501105, gamma=0.864909
# rejected 0 points, remaining 30 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.56 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=67.725310, alpha=12.580417, gamma=0.550514
# rejected 0 points, remaining 50 points
# Iteration 2/20, params: mu=67.725346, alpha=12.580402, gamma=0.550514
# rejected 0 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.96 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=68.808780, alpha=11.623021, gamma=0.593005
# rejected 0 points, remaining 100 points
# Iteration 2/20, params: mu=68.808830, alpha=11.623002, gamma=0.593006
# rejected 0 points, remaining 100 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.44 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=69.273215, alpha=13.460298, gamma=0.479337
# rejected 0 points, remaining 150 points
# Iteration 2/20, params: mu=69.273244, alpha=13.460271, gamma=0.479338
# rejected 0 points, remaining 150 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.04 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=69.755513, alpha=13.665096, gamma=0.462422
# rejected 0 points, remaining 200 points
# Iteration 2/20, params: mu=69.755482, alpha=13.665127, gamma=0.462422
# rejected 0 points, remaining 200 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.75 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=0.8,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=70.271844, alpha=10.068423, gamma=1.154676
# rejected 0 points, remaining 10 points
# Iteration 2/20, params: mu=70.271825, alpha=10.068496, gamma=1.154671
# rejected 0 points, remaining 10 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.61 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=69.166073, alpha=18.238351, gamma=0.849131
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=69.166020, alpha=18.238377, gamma=0.849130
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.02 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=67.232184, alpha=12.064498, gamma=0.927619
# rejected 0 points, remaining 20 points
# Iteration 2/20, params: mu=67.232158, alpha=12.064516, gamma=0.927618
# rejected 0 points, remaining 20 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.39 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=67.146751, alpha=7.556384, gamma=0.958259
# rejected 0 points, remaining 30 points
# Iteration 2/20, params: mu=67.146713, alpha=7.556381, gamma=0.958260
# rejected 0 points, remaining 30 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.81 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=67.403370, alpha=13.873857, gamma=0.603530
# rejected 0 points, remaining 50 points
# Iteration 2/20, params: mu=67.403407, alpha=13.873854, gamma=0.603530
# rejected 0 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.23 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=68.644409, alpha=12.085752, gamma=0.675326
# rejected 0 points, remaining 100 points
# Iteration 2/20, params: mu=68.644433, alpha=12.085754, gamma=0.675326
# rejected 0 points, remaining 100 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.76 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=69.093683, alpha=14.383516, gamma=0.548332
# rejected 0 points, remaining 150 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.26 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=69.512299, alpha=14.784022, gamma=0.526892
# rejected 0 points, remaining 200 points
# Iteration 2/20, params: mu=69.512268, alpha=14.783999, gamma=0.526893
# rejected 0 points, remaining 200 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 4.11 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=0.9,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=70.379656, alpha=9.701547, gamma=1.300682
# rejected 0 points, remaining 10 points
# Iteration 2/20, params: mu=70.379678, alpha=9.701506, gamma=1.300684
# rejected 0 points, remaining 10 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.61 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=68.903260, alpha=19.762425, gamma=0.938231
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=68.903309, alpha=19.762410, gamma=0.938231
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.92 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=66.852716, alpha=12.822946, gamma=1.013145
# rejected 0 points, remaining 20 points
# Iteration 2/20, params: mu=66.852718, alpha=12.822903, gamma=1.013147
# rejected 0 points, remaining 20 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.38 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=66.899536, alpha=7.702548, gamma=1.047816
# rejected 0 points, remaining 30 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.78 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=66.917981, alpha=15.527938, gamma=0.652717
# rejected 0 points, remaining 50 points
# Iteration 2/20, params: mu=66.917999, alpha=15.527994, gamma=0.652715
# rejected 0 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.14 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=68.419856, alpha=12.599043, gamma=0.757651
# rejected 0 points, remaining 100 points
# Iteration 2/20, params: mu=68.419863, alpha=12.599017, gamma=0.757652
# rejected 0 points, remaining 100 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.66 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=68.825650, alpha=15.437196, gamma=0.617128
# rejected 0 points, remaining 150 points
# Iteration 2/20, params: mu=68.825618, alpha=15.437223, gamma=0.617128
# rejected 0 points, remaining 150 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.23 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=69.091069, alpha=16.187880, gamma=0.588801
# rejected 0 points, remaining 200 points
# Iteration 2/20, params: mu=69.091033, alpha=16.187880, gamma=0.588800
# rejected 0 points, remaining 200 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 4.08 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=1,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=70.506346, alpha=9.349014, gamma=1.445833
# rejected 0 points, remaining 10 points
# Iteration 2/20, params: mu=70.506384, alpha=9.349009, gamma=1.445833
# rejected 0 points, remaining 10 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.68 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=68.477046, alpha=21.652433, gamma=1.023230
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=68.477100, alpha=21.652407, gamma=1.023231
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.13 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=66.314262, alpha=13.781255, gamma=1.095193
# rejected 0 points, remaining 20 points
# Iteration 2/20, params: mu=66.314252, alpha=13.781296, gamma=1.095191
# rejected 0 points, remaining 20 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.60 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=66.536012, alpha=7.949126, gamma=1.133527
# rejected 0 points, remaining 30 points
# Iteration 2/20, params: mu=66.536049, alpha=7.949097, gamma=1.133529
# rejected 0 points, remaining 30 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.36 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=66.213009, alpha=17.626224, gamma=0.698359
# rejected 0 points, remaining 50 points
# Iteration 2/20, params: mu=66.213005, alpha=17.626197, gamma=0.698359
# rejected 0 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.11 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=68.141008, alpha=13.141161, gamma=0.840495
# rejected 59 points, remaining 41 points
# Iteration 2/20, params: mu=59.532014, alpha=15.857900, gamma=0.787068
# rejected 59 points, remaining 41 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.52 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=68.463033, alpha=16.608946, gamma=0.686169
# rejected 0 points, remaining 150 points
# Iteration 2/20, params: mu=68.463060, alpha=16.608937, gamma=0.686169
# rejected 0 points, remaining 150 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 4.18 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=68.409247, alpha=17.948705, gamma=0.648077
# rejected 0 points, remaining 200 points
# Iteration 2/20, params: mu=68.409222, alpha=17.948684, gamma=0.648078
# rejected 0 points, remaining 200 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 5.12 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=1.1,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=70.649012, alpha=9.015689, gamma=1.589985
# rejected 0 points, remaining 10 points
# Iteration 2/20, params: mu=70.648997, alpha=9.015717, gamma=1.589984
# rejected 0 points, remaining 10 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.63 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=67.829398, alpha=23.978221, gamma=1.104351
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=67.829386, alpha=23.978208, gamma=1.104351
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.14 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=65.566492, alpha=14.972643, gamma=1.173882
# rejected 0 points, remaining 20 points
# Iteration 2/20, params: mu=65.566468, alpha=14.972657, gamma=1.173881
# rejected 0 points, remaining 20 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.55 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=66.018870, alpha=8.306079, gamma=1.215483
# rejected 0 points, remaining 30 points
# Iteration 2/20, params: mu=66.018877, alpha=8.306061, gamma=1.215484
# rejected 0 points, remaining 30 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.09 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=65.214294, alpha=20.274772, gamma=0.740773
# rejected 0 points, remaining 50 points
# Iteration 2/20, params: mu=65.214253, alpha=20.274779, gamma=0.740773
# rejected 0 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.71 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=67.830030, alpha=13.681970, gamma=0.924406
# rejected 64 points, remaining 36 points
# Iteration 2/20, params: mu=56.666512, alpha=16.531877, gamma=0.872024
# rejected 64 points, remaining 36 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.17 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=68.013388, alpha=17.873732, gamma=0.755943
# rejected 104 points, remaining 46 points
# Iteration 2/20, params: mu=47.664473, alpha=24.497152, gamma=0.671412
# rejected 104 points, remaining 46 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.59 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=67.348056, alpha=20.159556, gamma=0.704684
# rejected 150 points, remaining 50 points
# Iteration 2/20, params: mu=24.499450, alpha=33.046549, gamma=0.579657
# rejected 150 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 4.04 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=1.2,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=70.804533, alpha=8.703944, gamma=1.733087
# rejected 0 points, remaining 10 points
# Iteration 2/20, params: mu=70.804509, alpha=8.703974, gamma=1.733085
# rejected 0 points, remaining 10 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.78 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=66.884995, alpha=26.823247, gamma=1.181886
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=66.884952, alpha=26.823260, gamma=1.181886
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.23 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=64.545002, alpha=16.435892, gamma=1.249419
# rejected 0 points, remaining 20 points
# Iteration 2/20, params: mu=64.544986, alpha=16.435858, gamma=1.249420
# rejected 0 points, remaining 20 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.59 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=65.301227, alpha=8.784728, gamma=1.293869
# rejected 7 points, remaining 23 points
# Iteration 2/20, params: mu=63.216672, alpha=9.367201, gamma=1.270894
# rejected 7 points, remaining 23 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.97 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=63.823318, alpha=23.609739, gamma=0.780271
# rejected 0 points, remaining 50 points
# Iteration 2/20, params: mu=63.823264, alpha=23.609709, gamma=0.780272
# rejected 0 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.35 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=67.534867, alpha=14.182774, gamma=1.009964
# rejected 68 points, remaining 32 points
# Iteration 2/20, params: mu=55.201138, alpha=16.735556, gamma=0.965135
# rejected 68 points, remaining 32 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.05 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=67.508222, alpha=19.191055, gamma=0.826971
# rejected 109 points, remaining 41 points
# Iteration 2/20, params: mu=44.970382, alpha=25.349133, gamma=0.754239
# rejected 109 points, remaining 41 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.75 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=65.736307, alpha=22.941957, gamma=0.758608
# rejected 154 points, remaining 46 points
# Iteration 2/20, params: mu=2.502902, alpha=39.343452, gamma=0.625316
# rejected 154 points, remaining 46 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 4.30 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=1.3,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=70.970153, alpha=8.414246, gamma=1.875154
# rejected 0 points, remaining 10 points
# Iteration 2/20, params: mu=70.970107, alpha=8.414250, gamma=1.875154
# rejected 0 points, remaining 10 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.73 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=65.546173, alpha=30.287924, gamma=1.256175
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=65.546206, alpha=30.287918, gamma=1.256176
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.64 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=63.167268, alpha=18.217069, gamma=1.322062
# rejected 0 points, remaining 20 points
# Iteration 2/20, params: mu=63.167214, alpha=18.217094, gamma=1.322062
# rejected 0 points, remaining 20 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.27 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=64.324169, alpha=9.398236, gamma=1.368950
# rejected 9 points, remaining 21 points
# Iteration 2/20, params: mu=60.340641, alpha=10.344392, gamma=1.335075
# rejected 9 points, remaining 21 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.76 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=61.908883, alpha=27.805150, gamma=0.817165
# rejected 0 points, remaining 50 points
# Iteration 2/20, params: mu=61.908889, alpha=27.805171, gamma=0.817165
# rejected 0 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.22 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=67.342485, alpha=14.598083, gamma=1.097750
# rejected 72 points, remaining 28 points
# Iteration 2/20, params: mu=54.548322, alpha=16.701986, gamma=1.061996
# rejected 72 points, remaining 28 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 4.35 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=67.020456, alpha=20.501641, gamma=0.899807
# rejected 113 points, remaining 37 points
# Iteration 2/20, params: mu=45.715422, alpha=25.444267, gamma=0.844532
# rejected 113 points, remaining 37 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 5.61 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=63.327087, alpha=26.455242, gamma=0.809865
# rejected 158 points, remaining 42 points
# Iteration 2/20, params: mu=-30.681855, alpha=47.567444, gamma=0.667741
# rejected 158 points, remaining 42 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 6.60 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=1.4,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=71.143278, alpha=8.145679, gamma=2.016262
# rejected 0 points, remaining 10 points
# Iteration 2/20, params: mu=71.143303, alpha=8.145672, gamma=2.016262
# ...
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.56 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=69.264494, alpha=14.852654, gamma=1.379943
# rejected 79 points, remaining 21 points
# Iteration 2/20, params: mu=92.752662, alpha=13.525985, gamma=1.403299
# rejected 80 points, remaining 20 points
# Iteration 3/20, params: mu=97.974147, alpha=13.258896, gamma=1.408252
# rejected 80 points, remaining 20 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.27 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=67.595901, alpha=23.519206, gamma=1.135073
# rejected 123 points, remaining 27 points
# Iteration 2/20, params: mu=114.517284, alpha=20.217680, gamma=1.170237
# rejected 124 points, remaining 26 points
# Iteration 3/20, params: mu=123.316335, alpha=19.614497, gamma=1.177286
# rejected 124 points, remaining 26 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 4.64 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=46.873952, alpha=43.855061, gamma=0.948116
# rejected 166 points, remaining 34 points
# Iteration 2/20, params: mu=-260.175063, alpha=90.032123, gamma=0.781396
# rejected 166 points, remaining 34 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 5.72 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=1.7,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=71.688910, alpha=7.447765, gamma=2.434933
# rejected 2 points, remaining 8 points
# Iteration 2/20, params: mu=73.410045, alpha=7.106624, gamma=2.458086
# rejected 2 points, remaining 8 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.97 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=53.074256, alpha=53.174947, gamma=1.527943
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=53.074266, alpha=53.174917, gamma=1.527943
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.60 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=51.458825, alpha=29.796930, gamma=1.589432
# rejected 4 points, remaining 16 points
# Iteration 2/20, params: mu=39.313956, alpha=32.756504, gamma=1.552032
# rejected 4 points, remaining 16 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.22 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=55.977119, alpha=13.568566, gamma=1.642539
# rejected 14 points, remaining 16 points
# Iteration 2/20, params: mu=31.295398, alpha=16.868151, gamma=1.568354
# rejected 14 points, remaining 16 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.79 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=44.503636, alpha=58.730594, gamma=0.944151
# rejected 0 points, remaining 50 points
# Iteration 2/20, params: mu=44.503605, alpha=58.730598, gamma=0.944151
# rejected 0 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.44 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=71.902919, alpha=14.482099, gamma=1.481813
# rejected 81 points, remaining 19 points
# Iteration 2/20, params: mu=139.487211, alpha=11.620606, gamma=1.536292
# rejected 82 points, remaining 18 points
# Iteration 3/20, params: mu=151.716760, alpha=11.201348, gamma=1.545306
# rejected 82 points, remaining 18 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 4.18 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=69.820871, alpha=23.868330, gamma=1.221099
# rejected 125 points, remaining 25 points
# Iteration 2/20, params: mu=184.597135, alpha=17.204645, gamma=1.296911
# rejected 127 points, remaining 23 points
# Iteration 3/20, params: mu=219.402000, alpha=15.613090, gamma=1.319142
# rejected 128 points, remaining 22 points
# Iteration 4/20, params: mu=241.380145, alpha=14.681076, gamma=1.333194
# rejected 128 points, remaining 22 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 4.92 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=35.711034, alpha=53.219591, gamma=0.989278
# rejected 167 points, remaining 33 points
# Iteration 2/20, params: mu=-404.345114, alpha=111.808900, gamma=0.819005
# rejected 167 points, remaining 33 points
# Iteration 3/20, params: mu=-404.345103, alpha=111.808899, gamma=0.819005
# rejected 167 points, remaining 33 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 5.43 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=1.8,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=71.874456, alpha=7.243574, gamma=2.573363
# rejected 2 points, remaining 8 points
# Iteration 2/20, params: mu=73.632211, alpha=6.953058, gamma=2.593433
# rejected 2 points, remaining 8 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.86 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=46.915099, alpha=62.142457, gamma=1.591184
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=46.915200, alpha=62.142486, gamma=1.591183
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.30 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=45.951201, alpha=34.240347, gamma=1.651898
# rejected 5 points, remaining 15 points
# Iteration 2/20, params: mu=25.346928, alpha=38.724121, gamma=1.603648
# rejected 5 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.81 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=52.067157, alpha=15.165296, gamma=1.705856
# rejected 15 points, remaining 15 points
# Iteration 2/20, params: mu=15.419624, alpha=19.457247, gamma=1.621452
# rejected 15 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.37 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=35.819207, alpha=72.163185, gamma=0.971905
# rejected 0 points, remaining 50 points
# Iteration 2/20, params: mu=35.819221, alpha=72.163167, gamma=0.971905
# rejected 0 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.85 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=76.533964, alpha=13.861480, gamma=1.588117
# rejected 83 points, remaining 17 points
# Iteration 2/20, params: mu=226.424600, alpha=9.468800, gamma=1.681455
# rejected 84 points, remaining 16 points
# Iteration 3/20, params: mu=251.602633, alpha=8.923545, gamma=1.695838
# rejected 84 points, remaining 16 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.49 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=74.316367, alpha=23.723261, gamma=1.311893
# rejected 128 points, remaining 22 points
# Iteration 2/20, params: mu=333.093076, alpha=13.016820, gamma=1.449221
# rejected 131 points, remaining 19 points
# Iteration 3/20, params: mu=435.212013, alpha=10.324476, gamma=1.501386
# rejected 131 points, remaining 19 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 4.19 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=19.457299, alpha=65.354699, gamma=1.028136
# rejected 169 points, remaining 31 points
# Iteration 2/20, params: mu=-641.569835, alpha=143.466374, gamma=0.849531
# rejected 169 points, remaining 31 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 4.79 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=1.9,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=72.059800, alpha=7.050032, gamma=2.711432
# rejected 3 points, remaining 7 points
# Iteration 2/20, params: mu=75.622417, alpha=6.574446, gamma=2.745424
# rejected 3 points, remaining 7 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.79 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=38.752009, alpha=72.954271, gamma=1.653117
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=38.751968, alpha=72.954253, gamma=1.653117
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.30 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=38.775926, alpha=39.537424, gamma=1.713133
# rejected 6 points, remaining 14 points
# Iteration 2/20, params: mu=4.967982, alpha=46.127902, gamma=1.653074
# rejected 6 points, remaining 14 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.77 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=46.991915, alpha=17.050158, gamma=1.767730
# rejected 16 points, remaining 14 points
# Iteration 2/20, params: mu=-7.601164, alpha=22.668455, gamma=1.671809
# rejected 16 points, remaining 14 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.29 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=24.151307, alpha=89.213376, gamma=0.998436
# rejected 0 points, remaining 50 points
# Iteration 2/20, params: mu=24.151348, alpha=89.213378, gamma=0.998436
# rejected 0 points, remaining 50 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.94 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=84.123923, alpha=13.010981, gamma=1.698982
# rejected 84 points, remaining 16 points
# Iteration 2/20, params: mu=345.729176, alpha=7.766324, gamma=1.824232
# rejected 86 points, remaining 14 points
# Iteration 3/20, params: mu=441.397271, alpha=6.509180, gamma=1.866635
# rejected 86 points, remaining 14 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.67 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=82.366832, alpha=23.027709, gamma=1.407945
# rejected 130 points, remaining 20 points
# Iteration 2/20, params: mu=544.574549, alpha=9.809746, gamma=1.601001
# rejected 133 points, remaining 17 points
# Iteration 3/20, params: mu=726.110203, alpha=7.036243, gamma=1.674874
# rejected 134 points, remaining 16 points
# Iteration 4/20, params: mu=804.498352, alpha=6.072330, gamma=1.707472
# rejected 134 points, remaining 16 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 4.82 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=-4.193230, alpha=81.176174, gamma=1.064798
# rejected 170 points, remaining 30 points
# Iteration 2/20, params: mu=-972.652123, alpha=183.345430, gamma=0.881242
# rejected 170 points, remaining 30 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 6.01 seconds
# --------------------------------------------------
#
#
# Filepath: data/gev-mu=70,alpha=10,gamma=2,N=e6.csv
# Fitting with 10 bins...
# Iteration 1/20, params: mu=72.243745, alpha=6.865327, gamma=2.849247
# rejected 3 points, remaining 7 points
# Iteration 2/20, params: mu=75.837376, alpha=6.464885, gamma=2.878338
# rejected 3 points, remaining 7 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 0.99 seconds
# --------------------------------------------------
#
#
# Fitting with 15 bins...
# Iteration 1/20, params: mu=27.979584, alpha=85.982857, gamma=1.713983
# rejected 0 points, remaining 15 points
# Iteration 2/20, params: mu=27.979554, alpha=85.982850, gamma=1.713983
# rejected 0 points, remaining 15 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 1.79 seconds
# --------------------------------------------------
#
#
# Fitting with 20 bins...
# Iteration 1/20, params: mu=29.450117, alpha=45.844162, gamma=1.773357
# rejected 6 points, remaining 14 points
# Iteration 2/20, params: mu=-12.550201, alpha=53.201243, gamma=1.715699
# rejected 6 points, remaining 14 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 2.51 seconds
# --------------------------------------------------
#
#
# Fitting with 30 bins...
# Iteration 1/20, params: mu=40.422561, alpha=19.266349, gamma=1.828417
# rejected 17 points, remaining 13 points
# Iteration 2/20, params: mu=-41.056654, alpha=26.655994, gamma=1.719630
# rejected 17 points, remaining 13 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.04 seconds
# --------------------------------------------------
#
#
# Fitting with 50 bins...
# Iteration 1/20, params: mu=8.485343, alpha=110.902676, gamma=1.023892
# rejected 18 points, remaining 32 points
# Iteration 2/20, params: mu=-119.512930, alpha=151.021952, gamma=0.925008
# rejected 18 points, remaining 32 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 3.53 seconds
# --------------------------------------------------
#
#
# Fitting with 100 bins...
# Iteration 1/20, params: mu=96.007567, alpha=11.972812, gamma=1.814387
# rejected 86 points, remaining 14 points
# Iteration 2/20, params: mu=604.414733, alpha=5.581825, gamma=1.997869
# rejected 88 points, remaining 12 points
# Iteration 3/20, params: mu=801.822446, alpha=4.194337, gamma=2.065810
# rejected 88 points, remaining 12 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 4.21 seconds
# --------------------------------------------------
#
#
# Fitting with 150 bins...
# Iteration 1/20, params: mu=95.779470, alpha=21.780105, gamma=1.509621
# rejected 132 points, remaining 18 points
# Iteration 2/20, params: mu=903.684670, alpha=6.763272, gamma=1.771282
# rejected 135 points, remaining 15 points
# Iteration 3/20, params: mu=1220.358373, alpha=4.242528, gamma=1.873748
# rejected 136 points, remaining 14 points
# Iteration 4/20, params: mu=1378.334264, alpha=3.327731, gamma=1.926839
# rejected 137 points, remaining 13 points
# Iteration 5/20, params: mu=1558.654317, alpha=2.496662, gamma=1.989443
# rejected 137 points, remaining 13 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 5.12 seconds
# --------------------------------------------------
#
#
# Fitting with 200 bins...
# Iteration 1/20, params: mu=-38.605384, alpha=101.930888, gamma=1.099373
# rejected 172 points, remaining 28 points
# Iteration 2/20, params: mu=-1538.754064, alpha=243.922603, gamma=0.904306
# rejected 172 points, remaining 28 points
# Iteration 3/20, params: mu=-1538.754047, alpha=243.922602, gamma=0.904306
# rejected 172 points, remaining 28 points
# VWLS fit completed.
# Parameters saved to data/Results/calc_param_for_c.csv
# took time: 5.86 seconds
# --------------------------------------------------
