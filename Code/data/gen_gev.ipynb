# %%
import numpy as np
from scipy.stats import genextreme
import pandas as pd

# Generated Data

N = 100

# Dataset 1: Frechet
mu    = 70
alpha = 10
gamma = -0.3
data = genextreme.rvs(c=-gamma, loc=mu, scale=alpha, size=N, random_state=42)

filename=f'gev-mu={mu},alpha={alpha},gamma={gamma},N={N}.csv'

with open(filename, "w") as f:
    for x in data:
        f.write(f"{x}\n")

print(f"File created: {filename}")

# Load Data
df   = pd.read_csv(filename)

data = df.values
data
# Out:
# File created: gev-mu=70,alpha=10,gamma=-0.3,N=100.csv
# array([[89.71971296],
#        [79.83061794],
#        [76.04794088],
#        [63.19336593],
#        [63.1923638 ],
#        [57.71458752],
#        [84.708781  ],
#        [76.11345727],
#        [79.10613151],
#        [53.25657013],
#        [91.62779831],
#        [83.29359151],
#        [65.3194564 ],
#        [64.21557521],
#        [64.27522591],
#        [68.21488785],
#        [74.11129474],
#        [71.70485653],
#        [67.83272498],
#        [76.40105671],
#        [62.48248637],
#        [67.85984561],
#        [69.95872176],
#        [72.33361604],
#        [81.5591844 ],
#        [64.87299544],
#        [73.83889499],
#        [75.88184806],
#        [56.66809208],
#        [76.28542624],
#        [63.7795394 ],
#        [58.26719424],
#        [89.56615723],
#        [91.14353534],
#        [82.3820825 ],
#        [68.2256971 ],
#        [60.39260024],
#        [78.40877761],
#        [71.91930705],
#        [61.66975188],
#        [73.34614683],
#        [55.34131991],
#        [86.87919929],
#        [66.8453158 ],
#        [77.7914246 ],
#        [68.43116669],
#        [73.98987099],
#        [74.68136225],
#        [64.32971739],
#        [91.58939807],
#        [81.21776478],
#        [88.83052693],
#        [86.08998219],
#        [76.0277312 ],
#        [87.63041552],
#        [59.8539341 ],
#        [64.73991134],
#        [56.54675012],
#        [68.82033276],
#        [70.56086919],
#        [67.23418776],
#        [83.14858401],
#        [69.69613776],
#        [67.52515089],
#        [74.57690204],
#        [62.54607476],
#        [82.15738512],
#        [58.95366695],
#        [94.23317523],
#        [81.12103071],
#        [64.83858417],
#        [48.67523231],
#        [82.64295015],
#        [79.07002853],
#        [79.73863469],
#        [81.08853265],
#        [58.91877492],
#        [69.74309571],
#        [61.36412928],
#        [84.57175144],
#        [76.70997802],
#        [68.97763284],
#        [58.15263835],
#        [68.41015665],
#        [68.81616586],
#        [79.75704536],
#        [77.09872461],
#        [85.70241817],
#        [72.75224875],
#        [61.54994439],
#        [79.26051158],
#        [80.74311623],
#        [75.06153384],
#        [81.07843592],
#        [73.31044129],
#        [74.05887559],
#        [71.58951212],
#        [54.08874213],
#        [60.95214263]])
